# %% [markdown]
# <a href="https://colab.research.google.com/github/DOLOJROBED/Machine-Learning-with--python-boot-camp/blob/main/Weekend_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1 - Understading variables vs Quoted text

# %% [markdown]
# part 1 - Understanding Vasriables vs Quoted text

# %% [markdown]
# In [1]

# %%
# Student: Obed A. Dolo,Jr- 24 May 2026
# Problem 1
Liberia = 1847
print(Liberia) # The first line is 1847 because it is a Variable it give exactly whta it is equal to.
print("Liberia") # the second line is a Print statement which result exactly as it is in the quotation mark.
# Out:
# 1847
# Liberia

# %% [markdown]
# In [10]

# %%
# problem 2
Country = Liberia
print("Liberia became dependent in" , Country)
# Out:
# Liberia became independent in 1847

# %% [markdown]
# In [17]

# %%
# problem 3
Year = "1847"
print('The year is "1847"')
# Out:
# The year is "1847"

# %% [markdown]
# Part 2 - Creating Variables with different Data type

# %% [markdown]
# In [41]

# %%
# problem 4
market_name = "Gobacop Market"
total_market_table = 150
price_per_bag =3200.50
is_market_open = True
print(type(market_name))
print(type(total_market_table))
print(type(price_per_bag))
print(type(is_market_open))
print("Market Name:" , market_name)
print("Total Market Table:" ,total_market_table)
print("Price per Bags:" , price_per_bag)
print("Market Open Today:" , is_market_open)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# Market Name: Gobacop Market
# Total Market Table: 150
# Price per Bags: 3200.5
# Market Open Today: True

# %% [markdown]
# In [39]

# %%
# problem 5
current_price = 2550.75
quantity = 10
tota_cost = current_price * quantity
print("Total cost for 10 bags:" , total_cost, "LRD")
# Out:
# Total cost for 10 bags: 25507.5 LRD

# %% [markdown]
# In [43]

# %%
# problem 6
has_scarcity = False
is_rainy = True
print("Scarcity today:" , has_scarcity)
print("Rainy Today:" , is_rainy)
# Out:
# Scarcity today: False
# Rainy Today: True

# %% [markdown]
# Part 3 - Arithmetic with Variables

# %% [markdown]
# IN [57]

# %%
# problem 7 - Total revenue
price_per_bag = 800
quantity = 25
total_revenue= price_per_bag* quantity
print("Price Per Bag of cassava is" , price_per_bag)
print("The Trader buys" , quantity , "of Cassava")
print("Total Revenue:" ,total_revenue)
# Out:
# Price Per Bag of cassava is 800
# The Trader buys 25 of Cassava
# Total Revenue: 20000

# %% [markdown]
# In [66]

# %%
# problem 8 - Price Increase
today_price = 3200
increase_price= 150
tomorrow_price = today_price+increase_price
print("Today price:" , today_price , "LRD")
print("Tomorrow it will incraese by:" , increase_price , "LRD")
print("Tomorrow exact price will be:" , tomorrow_price)
# Out:
# Today price: 3200 LRD
# Tomorrow it will incraese by: 150 LRD
# Tomorrow exact price will be: 3350

# %% [markdown]
# In [73]

# %%
# problem 9 - Splitting Cost
onion_cost = 1800
traders = 3
cost_per_trader = 1800/3
print("A bag of onion is cost:" , onion_cost , "LRD")
print("It was shared between:" , traders , "traders")
print("Cost Per Traders:" , cost_per_trader , "LRD")
# Out:
# A bag of onion is cost: 1800 LRD
# It was shared between: 3 traders
# Cost Per Traders: 600.0 LRD

# %% [markdown]
# In [77]

# %%
# problem 10 - Discount on a galllon of palm oil
original_price = 2500
discount_rate = 0.10
discount_amount = + original_price*discount_rate
final_price = original_price-discount_amount
print("Discount Amount:" , discount_amount)
print("Final Price:" , final_price)
# Out:
# Discount Amount: 250.0
# Final Price: 2250.0

# %% [markdown]
# In [83]

# %%
# problem 11 - variables names Vs quoted strings
print(item) = cassava
print("item") = Item
print(price) = 800
print("Price") = price
# print(item) print cassava because it did not have quoted sting on it which is a variable.
# print("item") print item because it is a quoted string containing the quotation mark.

# %% [markdown]
# In [84]

# %%
# problem 12 - Using variables inside messages
product = "pepper"
cost = 150.50
print("One bag of" , product , "cost" , cost)
# Out:
# One bag of pepper cost 150.5
