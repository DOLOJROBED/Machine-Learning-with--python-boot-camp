# %% [markdown]
# <a href="https://colab.research.google.com/github/DOLOJROBED/Machine-Learning-with--python-boot-camp/blob/main/python_reffresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
# create a labeled storage basket and put  a number inside
tomato_price = 150
pepper_price = 80

# pull the value out of the basket
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables (ML Anchor)

# %%
#--- THE CLUES (Features grouped as X)---
rainfall_mm = 45.2  # clue 1
bags_available = 100 # clue 2

# --- THE GOAL (Target labeled as y)---
predicted_price = 3200 # what our AI caculates
