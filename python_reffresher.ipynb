# %% [markdown]
# <a href="https://colab.research.google.com/github/DOLOJROBED/Machine-Learning-with--python-boot-camp/blob/main/python_reffresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
# create a labeled storage basket and put  a number inside
tomato_price = 150
pepper_price = 80

# pull the value out of the basket
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables (ML Anchor)

# %%
#--- THE CLUES (Features grouped as X)---
rainfall_mm = 45.2  # clue 1
bags_available = 100 # clue 2

# --- THE GOAL (Target labeled as y)---
predicted_price = 3200 # what our AI caculates

# %% [markdown]
# TYPE CONVERSION

# %%
raw_input = "150"
price = int(raw_input)   # turns strings into integers
print(price + 50)        # 200

total_cost = 34.5
message = "your total is LRD " + str(total_cost)
print (message)
# Out:
# 200
# your total is LRD 34.5

# %%
goods = ["tomatoes", "peppers", "onions", "rice"]
print(goods)   # ['tomatoes', 'pepper', 'onions', 'rice']
print(goods[0])  # tomatoes
print(goods[2])  #onions
# Out:
# ['tomatoes', 'peppers', 'onions', 'rice']
# tomatoes
# onions

# %%
print(goods[0:2])
print(goods[0:3])
# Out:
# ['tomatoes', 'peppers']
# ['tomatoes', 'peppers', 'onions']

# %% [markdown]
# LIST ML ANCHOR

# %%
loose_list = [3100, 3200, 3250]
# ML- ready crate: double brackets [[]]
crate_matrix = [[3100], [3200], [3150]]

print("Rejected by AI:" , loose_list)
print("Accepited by AI (crate):" , crate_matrix)
# Out:
# Rejected by AI: [3100, 3200, 3250]
# Accepited by AI (crate): [[3100], [3200], [3150]]

# %% [markdown]
# F-STRINGS FOR CLEAN REPORTING

# %%
model_accuracy = 0.9456
predicted_value = 3500

print(f"Ma Christiana, our market AI model is {model_accuracy:.1%} accurate.")
print(f"predicted price of rice at red light is: {predicted_value}.")
# Out:
# Ma Christiana, our market AI model is 94.6% accurate.
# predicted price of rice at red light is: 3500.

# %% [markdown]
# DICTIONARIES

# %%
stalls_prices = {
    "Torborgi": 700,
    "Fried greens": 850,
    "Cabbage": 750

}
print(stalls_prices["Torborgi"]) # 700
print(stalls_prices["Fried greens"])  # 850
# Out:
# 700
# 850
